# %% [markdown]
# # estadistica

# %%
x<-rnorm(30)

# %%
x
# Out:
#  [1] -0.94957307  0.61767164  0.07327601 -0.34940826 -0.26177752 -0.25985867
#  [7] -0.88228440  0.07371451  0.82515347  0.91214600  1.25879688  2.26073273
# [13] -0.49949541 -0.28633756  1.12608429 -0.64659442  1.21036037 -1.14415444
# [19] -0.53931065  0.70732688 -2.93640792  1.45864894 -1.18780456 -1.90056743
# [25]  1.62553405 -0.02527294  1.60846606  0.25357403 -1.02527463 -0.50311280

# %%
hist(x)
# Out:
# Plot with title "Histogram of x"

# %%
hist(x,col="blue")
# Out:
# Plot with title "Histogram of x"
